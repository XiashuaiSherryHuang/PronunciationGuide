# %%
# !pip install levenshtein
#https://maxbachmann.github.io/Levenshtein/levenshtein.html#distance
# !pip install g2p_en
#https://github.com/Kyubyong/g2p
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: levenshtein in /usr/local/lib/python3.10/dist-packages (0.21.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from levenshtein) (3.1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: g2p_en in /usr/local/lib/python3.10/dist-packages (2.1.0)
# Requirement already satisfied: numpy>=1.13.1 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (1.22.4)
# Requirement already satisfied: nltk>=3.2.4 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (3.8.1)
# Requirement already satisfied: inflect>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (6.0.4)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (0.1.3)
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from inflect>=0.3.1->g2p_en) (1.10.7)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (4.65.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.1->inflect>=0.3.1->g2p_en) (4.5.0)

# %%
import os
import pandas as pd
import numpy as np
import Levenshtein as lev
from g2p_en import G2p

# %%
class Evaluator():
    def __init__(self, pred_path, actual_path):
        self.pred_path = pred_path
        self.actual_path = actual_path
        super().__init__()

    @staticmethod
    def get_target_arpabet():
        '''Return ARPABET of the given paragraph'''
        TARGET_TEXT = '''Please call Stella. Ask her to bring these things with her from the store: Six spoons of fresh snow peas, five thick slabs of blue cheese, and maybe a snack for her brother Bob. We also need a small plastic snake and a big toy frog for the kids. She can scoop these things into three red bags, and we will go meet her Wednesday at the train station.'''
        ## Grapheme To Phoneme Conversion
        g2p = G2p()
        target_p = ''.join(g2p(TARGET_TEXT))
        ##print('Target arpabet is {}'.format(target_p))
        return target_p

    @staticmethod
    def calculate_distance(pred_p, target_p, weights=(1, 1, 1), score_cutoff=None):
        '''
        Levenshtein distance is from S1 to S2, here is from pred_p to target_p
        weights for the three operations in the form (insertion, deletion, substitution)
        If the distance is bigger than score_cutoff, score_cutoff + 1 is returned instead
        '''
        dist = lev.distance(pred_p, target_p, weights=weights, score_cutoff=score_cutoff)
        return dist

    @staticmethod
    def read_txt(input_file):
        with open(input_file, "r") as file:
            text = file.read()
        return text

    def process_files(self):
        res = []
        actual_file_list = os.listdir(self.actual_path)
        pred_file_list = os.listdir(self.pred_path)
        ###actual files can starting with Capital while pred files not, so use it for loop as a small trick
        for file_name in actual_file_list:
            print(file_name)
            one_row = {'file': file_name}
            target_p = self.get_target_arpabet()
            actual_p = self.read_txt(os.path.join(self.actual_path, file_name))
            dist_a = self.calculate_distance(actual_p, target_p)
            dist2_a = self.calculate_distance(actual_p, target_p, weights=(1, 1, 2))
            one_row.update({'adist': dist_a, 'adist2': dist2_a})
            if file_name.lower() in pred_file_list:
              pred_p = self.read_txt(os.path.join(self.pred_path, file_name.lower()))
              dist = self.calculate_distance(pred_p, target_p)
              dist2 = self.calculate_distance(pred_p, target_p, weights=(1, 1, 2))
              print(f'Processed file {file_name}, distance {dist} and distance 2 is {dist2}')
              one_row.update({'pdist': dist, 'pdist2': dist2})

            res.append(one_row)

        return pd.DataFrame(res)

    @staticmethod
    def save(df, file_path='res.csv'):
        df.to_csv(file_path, index=False)
        return

# %%
base_path = 'baseline_arpa/'
actual_path = 'arpa_transcripts/'
finetuned_path = 'finetuned_arpa/'

# %%
print(len(os.listdir(base_path)))
print(len(os.listdir(actual_path)))
print(len(os.listdir(finetuned_path)))
# Out:
# 96
# 100
# 97

# %%
base_evator = Evaluator(base_path, actual_path)
finetuned_evator = Evaluator(finetuned_path, actual_path)

# %%
df_base = base_evator.process_files()
# Out:
# bulgarian1.txt
# Processed file bulgarian1.txt, distance 24 and distance 2 is 30
# mankanya1.txt
# Processed file mankanya1.txt, distance 103 and distance 2 is 129
# Mandarin1.txt
# Processed file Mandarin1.txt, distance 60 and distance 2 is 86
# Spanish3.txt
# Processed file Spanish3.txt, distance 83 and distance 2 is 110
# Portuguese3.txt
# Processed file Portuguese3.txt, distance 75 and distance 2 is 100
# Kirghiz1.txt
# Processed file Kirghiz1.txt, distance 69 and distance 2 is 94
# dari6.txt
# Processed file dari6.txt, distance 37 and distance 2 is 48
# danish2.txt
# Processed file danish2.txt, distance 20 and distance 2 is 23
# arabic17.txt
# Processed file arabic17.txt, distance 43 and distance 2 is 58
# arabic53.txt
# Processed file arabic53.txt, distance 53 and distance 2 is 67
# English55.txt
# Processed file English55.txt, distance 19 and distance 2 is 23
# greek2.txt
# Processed file greek2.txt, distance 89 and distance 2 is 103
# korean20.txt
# Processed file korean20.txt, distance 20 and distance 2 is 25
# tagalog5.txt
# Processed file tagalog5.txt, distance 16 and distance 2 is 17
# arabic42.txt
# English112.txt
# Processed file English112.txt, distance 51 and distance 2 is 61
# italian22.txt
# Processed file italian22.txt, distance 31 and distance 2 is 40
# Bosnian3.txt
# Processed file Bosnian3.txt, distance 51 and distance 2 is 66
# hindi3.txt
# Processed file hindi3.txt, distance 25 and distance 2 is 29
# tamil3.txt
# Processed file tamil3.txt, distance 43 and distance 2 is 57
# german15.txt
# Processed file german15.txt, distance 21 and distance 2 is 24
# portuguese25.txt
# Processed file portuguese25.txt, distance 46 and distance 2 is 57
# dutch41.txt
# Processed file dutch41.txt, distance 45 and distance 2 is 58
# serbian8.txt
# Processed file serbian8.txt, distance 68 and distance 2 is 95
# spanish55.txt
# Processed file spanish55.txt, distance 104 and distance 2 is 143
# Tibetan2.txt
# Processed file Tibetan2.txt, distance 137 and distance 2 is 179
# spanish31.txt
# Processed file spanish31.txt, distance 71 and distance 2 is 95
# ukranian8.txt
# Processed file ukranian8.txt, distance 91 and distance 2 is 118
# luba-kasai1.txt
# Processed file luba-kasai1.txt, distance 61 and distance 2 is 79
# georgian5.txt
# Processed file georgian5.txt, distance 97 and distance 2 is 125
# russian20.txt
# Processed file russian20.txt, distance 28 and distance 2 is 32
# arabic24.txt
# Processed file arabic24.txt, distance 175 and distance 2 is 220
# spanish58.txt
# Processed file spanish58.txt, distance 39 and distance 2 is 54
# Hebrew3.txt
# Processed file Hebrew3.txt, distance 28 and distance 2 is 31
# italian12.txt
# Processed file italian12.txt, distance 30 and distance 2 is 35
# cantonese1.txt
# Processed file cantonese1.txt, distance 113 and distance 2 is 165
# mandarin51.txt
# Processed file mandarin51.txt, distance 69 and distance 2 is 95
# german21.txt
# Processed file german21.txt, distance 24 and distance 2 is 31
# English12.txt
# Processed file English12.txt, distance 53 and distance 2 is 56
# french6.txt
# Processed file french6.txt, distance 38 and distance 2 is 47
# macedonian1.txt
# Processed file macedonian1.txt, distance 32 and distance 2 is 44
# Tatar1.txt
# Processed file Tatar1.txt, distance 15 and distance 2 is 16
# romanian4.txt
# Processed file romanian4.txt, distance 31 and distance 2 is 37
# gujarati5.txt
# Processed file gujarati5.txt, distance 26 and distance 2 is 32
# somali3.txt
# french34.txt
# Processed file french34.txt, distance 60 and distance 2 is 82
# mongolian3.txt
# Processed file mongolian3.txt, distance 56 and distance 2 is 83
# English38.txt
# Processed file English38.txt, distance 20 and distance 2 is 23
# croatian6.txt
# Processed file croatian6.txt, distance 98 and distance 2 is 109
# hausa7.txt
# Processed file hausa7.txt, distance 71 and distance 2 is 114
# agny1.txt
# romanian10.txt
# Processed file romanian10.txt, distance 41 and distance 2 is 54
# turkish9.txt
# Processed file turkish9.txt, distance 66 and distance 2 is 96
# Spanish19.txt
# Processed file Spanish19.txt, distance 102 and distance 2 is 119
# Portuguese4.txt
# Processed file Portuguese4.txt, distance 62 and distance 2 is 82
# norwegian5.txt
# Processed file norwegian5.txt, distance 38 and distance 2 is 51
# japanese12.txt
# Processed file japanese12.txt, distance 76 and distance 2 is 123
# English2.txt
# Processed file English2.txt, distance 14 and distance 2 is 14
# arabic1.txt
# Processed file arabic1.txt, distance 65 and distance 2 is 94
# russian14.txt
# Processed file russian14.txt, distance 67 and distance 2 is 78
# Quechua2.txt
# English44.txt
# Processed file English44.txt, distance 29 and distance 2 is 38
# Swedish2.txt
# Processed file Swedish2.txt, distance 27 and distance 2 is 32
# nepali9.txt
# Processed file nepali9.txt, distance 111 and distance 2 is 153
# serbian10.txt
# Processed file serbian10.txt, distance 53 and distance 2 is 66
# kurdish6.txt
# Processed file kurdish6.txt, distance 47 and distance 2 is 66
# farsi5.txt
# Processed file farsi5.txt, distance 117 and distance 2 is 128
# TokPisin1.txt
# Processed file TokPisin1.txt, distance 67 and distance 2 is 88
# farsi10.txt
# Processed file farsi10.txt, distance 85 and distance 2 is 108
# vietnamese9.txt
# Processed file vietnamese9.txt, distance 117 and distance 2 is 171
# uyghur4.txt
# Processed file uyghur4.txt, distance 50 and distance 2 is 72
# portuguese10.txt
# Processed file portuguese10.txt, distance 58 and distance 2 is 78
# Spanish17.txt
# Processed file Spanish17.txt, distance 26 and distance 2 is 29
# bengali2.txt
# Processed file bengali2.txt, distance 25 and distance 2 is 26
# slovak4.txt
# Processed file slovak4.txt, distance 40 and distance 2 is 60
# hungarian5.txt
# Processed file hungarian5.txt, distance 63 and distance 2 is 92
# wolof3.txt
# Processed file wolof3.txt, distance 57 and distance 2 is 86
# Russian3.txt
# Processed file Russian3.txt, distance 23 and distance 2 is 28
# Spanish4.txt
# Processed file Spanish4.txt, distance 95 and distance 2 is 136
# english139.txt
# Processed file english139.txt, distance 36 and distance 2 is 46
# konkani2.txt
# Processed file konkani2.txt, distance 56 and distance 2 is 74
# rwanda1.txt
# Processed file rwanda1.txt, distance 61 and distance 2 is 87
# Thai2.txt
# Processed file Thai2.txt, distance 79 and distance 2 is 110
# serbian17.txt
# Processed file serbian17.txt, distance 34 and distance 2 is 44
# arabic8.txt
# Processed file arabic8.txt, distance 42 and distance 2 is 56
# shilluk1.txt
# Processed file shilluk1.txt, distance 68 and distance 2 is 92
# English24.txt
# Processed file English24.txt, distance 34 and distance 2 is 42
# finnish1.txt
# Processed file finnish1.txt, distance 39 and distance 2 is 53
# turkish20.txt
# Processed file turkish20.txt, distance 109 and distance 2 is 158
# turkish15.txt
# Processed file turkish15.txt, distance 166 and distance 2 is 232
# yoruba3.txt
# Processed file yoruba3.txt, distance 60 and distance 2 is 92
# krio2.txt
# Processed file krio2.txt, distance 72 and distance 2 is 89
# spanish47.txt
# Processed file spanish47.txt, distance 74 and distance 2 is 94
# tagalog3.txt
# Processed file tagalog3.txt, distance 15 and distance 2 is 16
# Swedish4.txt
# Processed file Swedish4.txt, distance 50 and distance 2 is 67
# mandarin24.txt
# Processed file mandarin24.txt, distance 30 and distance 2 is 37
# german3.txt
# Processed file german3.txt, distance 39 and distance 2 is 50
# yakut1.txt
# Processed file yakut1.txt, distance 50 and distance 2 is 68
# arabic2.txt
# Processed file arabic2.txt, distance 22 and distance 2 is 22
# russian25.txt
# Processed file russian25.txt, distance 104 and distance 2 is 131

# %%
df_finetuned = finetuned_evator.process_files()
# Out:
# bulgarian1.txt
# Processed file bulgarian1.txt, distance 121 and distance 2 is 182
# mankanya1.txt
# Processed file mankanya1.txt, distance 168 and distance 2 is 228
# Mandarin1.txt
# Processed file Mandarin1.txt, distance 104 and distance 2 is 165
# Spanish3.txt
# Processed file Spanish3.txt, distance 167 and distance 2 is 239
# Portuguese3.txt
# Processed file Portuguese3.txt, distance 173 and distance 2 is 240
# Kirghiz1.txt
# Processed file Kirghiz1.txt, distance 155 and distance 2 is 229
# dari6.txt
# Processed file dari6.txt, distance 129 and distance 2 is 195
# danish2.txt
# Processed file danish2.txt, distance 94 and distance 2 is 142
# arabic17.txt
# Processed file arabic17.txt, distance 110 and distance 2 is 173
# arabic53.txt
# Processed file arabic53.txt, distance 120 and distance 2 is 173
# English55.txt
# Processed file English55.txt, distance 108 and distance 2 is 168
# greek2.txt
# Processed file greek2.txt, distance 173 and distance 2 is 244
# korean20.txt
# Processed file korean20.txt, distance 100 and distance 2 is 153
# tagalog5.txt
# Processed file tagalog5.txt, distance 110 and distance 2 is 172
# arabic42.txt
# English112.txt
# Processed file English112.txt, distance 120 and distance 2 is 170
# italian22.txt
# Processed file italian22.txt, distance 102 and distance 2 is 159
# Bosnian3.txt
# Processed file Bosnian3.txt, distance 114 and distance 2 is 180
# hindi3.txt
# Processed file hindi3.txt, distance 113 and distance 2 is 169
# tamil3.txt
# Processed file tamil3.txt, distance 110 and distance 2 is 170
# german15.txt
# Processed file german15.txt, distance 109 and distance 2 is 171
# portuguese25.txt
# Processed file portuguese25.txt, distance 148 and distance 2 is 214
# dutch41.txt
# Processed file dutch41.txt, distance 114 and distance 2 is 178
# serbian8.txt
# Processed file serbian8.txt, distance 142 and distance 2 is 212
# spanish55.txt
# Processed file spanish55.txt, distance 102 and distance 2 is 157
# Tibetan2.txt
# Processed file Tibetan2.txt, distance 179 and distance 2 is 257
# spanish31.txt
# Processed file spanish31.txt, distance 165 and distance 2 is 229
# ukranian8.txt
# Processed file ukranian8.txt, distance 138 and distance 2 is 196
# luba-kasai1.txt
# Processed file luba-kasai1.txt, distance 134 and distance 2 is 205
# georgian5.txt
# Processed file georgian5.txt, distance 170 and distance 2 is 243
# russian20.txt
# Processed file russian20.txt, distance 102 and distance 2 is 156
# arabic24.txt
# Processed file arabic24.txt, distance 213 and distance 2 is 283
# spanish58.txt
# Processed file spanish58.txt, distance 101 and distance 2 is 157
# Hebrew3.txt
# Processed file Hebrew3.txt, distance 108 and distance 2 is 160
# italian12.txt
# Processed file italian12.txt, distance 121 and distance 2 is 186
# cantonese1.txt
# Processed file cantonese1.txt, distance 155 and distance 2 is 230
# mandarin51.txt
# Processed file mandarin51.txt, distance 132 and distance 2 is 206
# german21.txt
# Processed file german21.txt, distance 119 and distance 2 is 188
# English12.txt
# Processed file English12.txt, distance 132 and distance 2 is 196
# french6.txt
# Processed file french6.txt, distance 123 and distance 2 is 192
# macedonian1.txt
# Processed file macedonian1.txt, distance 120 and distance 2 is 182
# Tatar1.txt
# Processed file Tatar1.txt, distance 99 and distance 2 is 154
# romanian4.txt
# Processed file romanian4.txt, distance 111 and distance 2 is 168
# gujarati5.txt
# Processed file gujarati5.txt, distance 117 and distance 2 is 180
# somali3.txt
# Processed file somali3.txt, distance 167 and distance 2 is 242
# french34.txt
# Processed file french34.txt, distance 124 and distance 2 is 189
# mongolian3.txt
# Processed file mongolian3.txt, distance 112 and distance 2 is 190
# English38.txt
# Processed file English38.txt, distance 111 and distance 2 is 170
# croatian6.txt
# Processed file croatian6.txt, distance 166 and distance 2 is 231
# hausa7.txt
# Processed file hausa7.txt, distance 109 and distance 2 is 166
# agny1.txt
# romanian10.txt
# Processed file romanian10.txt, distance 115 and distance 2 is 181
# turkish9.txt
# Processed file turkish9.txt, distance 121 and distance 2 is 187
# Spanish19.txt
# Processed file Spanish19.txt, distance 184 and distance 2 is 249
# Portuguese4.txt
# Processed file Portuguese4.txt, distance 140 and distance 2 is 209
# norwegian5.txt
# Processed file norwegian5.txt, distance 106 and distance 2 is 167
# japanese12.txt
# Processed file japanese12.txt, distance 129 and distance 2 is 204
# English2.txt
# Processed file English2.txt, distance 108 and distance 2 is 167
# arabic1.txt
# Processed file arabic1.txt, distance 121 and distance 2 is 180
# russian14.txt
# Processed file russian14.txt, distance 136 and distance 2 is 200
# Quechua2.txt
# English44.txt
# Processed file English44.txt, distance 110 and distance 2 is 164
# Swedish2.txt
# Processed file Swedish2.txt, distance 114 and distance 2 is 179
# nepali9.txt
# Processed file nepali9.txt, distance 129 and distance 2 is 193
# serbian10.txt
# Processed file serbian10.txt, distance 126 and distance 2 is 182
# kurdish6.txt
# Processed file kurdish6.txt, distance 129 and distance 2 is 192
# farsi5.txt
# Processed file farsi5.txt, distance 194 and distance 2 is 254
# TokPisin1.txt
# Processed file TokPisin1.txt, distance 129 and distance 2 is 188
# farsi10.txt
# Processed file farsi10.txt, distance 167 and distance 2 is 231
# vietnamese9.txt
# Processed file vietnamese9.txt, distance 116 and distance 2 is 172
# uyghur4.txt
# Processed file uyghur4.txt, distance 132 and distance 2 is 206
# portuguese10.txt
# Processed file portuguese10.txt, distance 121 and distance 2 is 186
# Spanish17.txt
# Processed file Spanish17.txt, distance 130 and distance 2 is 192
# bengali2.txt
# Processed file bengali2.txt, distance 120 and distance 2 is 179
# slovak4.txt
# Processed file slovak4.txt, distance 112 and distance 2 is 171
# hungarian5.txt
# Processed file hungarian5.txt, distance 125 and distance 2 is 197
# wolof3.txt
# Processed file wolof3.txt, distance 118 and distance 2 is 185
# Russian3.txt
# Processed file Russian3.txt, distance 96 and distance 2 is 150
# Spanish4.txt
# Processed file Spanish4.txt, distance 164 and distance 2 is 230
# english139.txt
# Processed file english139.txt, distance 124 and distance 2 is 187
# konkani2.txt
# Processed file konkani2.txt, distance 121 and distance 2 is 188
# rwanda1.txt
# Processed file rwanda1.txt, distance 105 and distance 2 is 155
# Thai2.txt
# Processed file Thai2.txt, distance 134 and distance 2 is 206
# serbian17.txt
# Processed file serbian17.txt, distance 106 and distance 2 is 160
# arabic8.txt
# Processed file arabic8.txt, distance 101 and distance 2 is 149
# shilluk1.txt
# Processed file shilluk1.txt, distance 129 and distance 2 is 197
# English24.txt
# Processed file English24.txt, distance 118 and distance 2 is 175
# finnish1.txt
# Processed file finnish1.txt, distance 113 and distance 2 is 176
# turkish20.txt
# Processed file turkish20.txt, distance 128 and distance 2 is 194
# turkish15.txt
# Processed file turkish15.txt, distance 143 and distance 2 is 213
# yoruba3.txt
# Processed file yoruba3.txt, distance 122 and distance 2 is 188
# krio2.txt
# Processed file krio2.txt, distance 141 and distance 2 is 196
# spanish47.txt
# Processed file spanish47.txt, distance 149 and distance 2 is 215
# tagalog3.txt
# Processed file tagalog3.txt, distance 95 and distance 2 is 144
# Swedish4.txt
# Processed file Swedish4.txt, distance 124 and distance 2 is 191
# mandarin24.txt
# Processed file mandarin24.txt, distance 111 and distance 2 is 171
# german3.txt
# Processed file german3.txt, distance 120 and distance 2 is 188
# yakut1.txt
# Processed file yakut1.txt, distance 121 and distance 2 is 190
# arabic2.txt
# Processed file arabic2.txt, distance 100 and distance 2 is 148
# russian25.txt
# Processed file russian25.txt, distance 190 and distance 2 is 264

# %%
##df.to_csv('res.csv', index=False)

# %%
df_base['dist'] = df_base['pdist'] - df_base['adist']
df_base['dist2'] = df_base['pdist2'] - df_base['adist2']

df_finetuned['dist'] = df_finetuned['pdist'] - df_finetuned['adist']
df_finetuned['dist2'] = df_finetuned['pdist2'] - df_finetuned['adist2']

# %%
df_base.describe()
# Out:
#             adist      adist2       pdist      pdist2        dist       dist2
# count  100.000000  100.000000   96.000000   96.000000   96.000000   96.000000
# mean   139.240000  208.700000   57.500000   75.760417  -78.531250 -128.802083
# std     31.936528   39.489034   32.888328   45.055462   24.453588   36.363550
# min     99.000000  152.000000   14.000000   14.000000 -119.000000 -189.000000
# 25%    119.750000  184.750000   31.000000   39.500000  -95.000000 -153.250000
# 50%    130.000000  200.500000   52.000000   67.000000  -83.000000 -136.500000
# 75%    151.750000  229.000000   71.250000   95.250000  -68.500000 -111.000000
# max    310.000000  422.000000  175.000000  232.000000   31.000000   20.000000

# %%
df_finetuned.describe()
# Out:
#             adist      adist2       pdist      pdist2       dist      dist2
# count  100.000000  100.000000   97.000000   97.000000  97.000000  97.000000
# mean   139.240000  208.700000  128.051546  191.020619  -8.360825 -14.113402
# std     31.936528   39.489034   24.779600   29.471024  12.063362  18.094587
# min     99.000000  152.000000   94.000000  142.000000 -35.000000 -57.000000
# 25%    119.750000  184.750000  111.000000  170.000000 -16.000000 -23.000000
# 50%    130.000000  200.500000  121.000000  187.000000  -8.000000 -14.000000
# 75%    151.750000  229.000000  136.000000  206.000000   0.000000  -3.000000
# max    310.000000  422.000000  213.000000  283.000000  20.000000  38.000000

# %%
def get_norm(y, ord=2):
  res = np.linalg.norm(y[~np.isnan(y)], ord=ord)
  return res

# %%
get_norm(df_base['dist'].values, ord=2)
# Out:
# 805.5153629819856

# %%
get_norm(df_finetuned['dist'].values, ord=2)
# Out:
# 144.05207391773297

# %%
get_norm(df_base['dist2'].values, ord=2)
# Out:
# 1310.8230239052104

# %%
get_norm(df_finetuned['dist2'].values, ord=2)
# Out:
# 225.28426487440262

# %%
from plotly.offline import iplot
import plotly.graph_objs as go
import plotly.express as px

# %%
df_base.head()
# Out:
#               file  adist  adist2  pdist  pdist2   dist  dist2
# 0   bulgarian1.txt    126     196   24.0    30.0 -102.0 -166.0
# 1    mankanya1.txt    183     250  103.0   129.0  -80.0 -121.0
# 2    Mandarin1.txt    127     210   60.0    86.0  -67.0 -124.0
# 3     Spanish3.txt    169     246   83.0   110.0  -86.0 -136.0
# 4  Portuguese3.txt    162     243   75.0   100.0  -87.0 -143.0

# %%
df_combined =  df_finetuned.merge(df_base, on=['file'], suffixes=('', '_base'))

# %%
df_combined.head()
# Out:
#               file  adist  adist2  pdist  pdist2  dist  dist2  adist_base  \
# 0   bulgarian1.txt    126     196  121.0   182.0  -5.0  -14.0         126
# 1    mankanya1.txt    183     250  168.0   228.0 -15.0  -22.0         183
# 2    Mandarin1.txt    127     210  104.0   165.0 -23.0  -45.0         127
# 3     Spanish3.txt    169     246  167.0   239.0  -2.0   -7.0         169
# 4  Portuguese3.txt    162     243  173.0   240.0  11.0   -3.0         162
#
#    adist2_base  pdist_base  pdist2_base  dist_base  dist2_base
# 0          196        24.0         30.0     -102.0      -166.0
# 1          250       103.0        129.0      -80.0      -121.0
# 2          210        60.0         86.0      -67.0      -124.0
# 3          246        83.0        110.0      -86.0      -136.0
# 4          243        75.0        100.0      -87.0      -143.0

# %%
df_finetuned['tag'] = 'finetuned'
df_base['tag'] = 'base'
df_all = df_finetuned.append(df_base)
# Out:
# <ipython-input-82-8244f89202e8>:3: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
df_all.head()
# Out:
#               file  adist  adist2  pdist  pdist2  dist  dist2        tag
# 0   bulgarian1.txt    126     196  121.0   182.0  -5.0  -14.0  finetuned
# 1    mankanya1.txt    183     250  168.0   228.0 -15.0  -22.0  finetuned
# 2    Mandarin1.txt    127     210  104.0   165.0 -23.0  -45.0  finetuned
# 3     Spanish3.txt    169     246  167.0   239.0  -2.0   -7.0  finetuned
# 4  Portuguese3.txt    162     243  173.0   240.0  11.0   -3.0  finetuned

# %%
fig = px.scatter(df_all , x = 'adist', y = 'pdist', color='tag')

fig.update_xaxes(title='Actual distance')
fig.update_yaxes(title='Predicted distance')
fig.update_layout(xaxis_range=[90,230])

fig['layout']['legend']['title']['font_size'] = 20
fig['layout']['legend']['font_size']=20
fig['layout']['xaxis']['title']['font_size'] = 20
fig['layout']['yaxis']['title']['font_size'] = 20

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="24444ecb-34a1-4317-9cd1-5175d64d2766" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24444ecb-34a1-4317-9cd1-5175d64d2766")) {                    Plotly.newPlot(                        "24444ecb-34a1-4317-9cd1-5175d64d2766",                        [{"hovertemplate":"tag=finetuned<br>adist=%{x}<br>pdist=%{y}<extra></extra>","legendgroup":"finetuned","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"finetuned","orientation":"v","showlegend":true,"x":[126,183,127,169,162,160,128,105,131,128,111,161,124,124,256,134,116,124,123,114,118,148,138,177,128,165,163,165,132,172,107,219,119,124,120,168,112,122,123,146,127,130,144,124,173,122,133,135,179,113,126,130,130,186,158,115,159,101,109,146,310,134,127,134,146,139,182,125,154,121,151,128,145,113,100,141,119,118,175,135,147,108,142,113,99,130,116,112,149,135,115,175,166,99,115,126,120,134,109,205],"xaxis":"x","y":[121.0,168.0,104.0,167.0,173.0,155.0,129.0,94.0,110.0,120.0,108.0,173.0,100.0,110.0,null,120.0,102.0,114.0,113.0,110.0,109.0,148.0,114.0,142.0,102.0,179.0,165.0,138.0,134.0,170.0,102.0,213.0,101.0,108.0,121.0,155.0,132.0,119.0,132.0,123.0,120.0,99.0,111.0,117.0,167.0,124.0,112.0,111.0,166.0,109.0,null,115.0,121.0,184.0,140.0,106.0,129.0,108.0,121.0,136.0,null,110.0,114.0,129.0,126.0,129.0,194.0,129.0,167.0,116.0,132.0,121.0,130.0,120.0,112.0,125.0,118.0,96.0,164.0,124.0,121.0,105.0,134.0,106.0,101.0,129.0,118.0,113.0,128.0,143.0,122.0,141.0,149.0,95.0,124.0,111.0,120.0,121.0,100.0,190.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"tag=base<br>adist=%{x}<br>pdist=%{y}<extra></extra>","legendgroup":"base","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"base","orientation":"v","showlegend":true,"x":[126,183,127,169,162,160,128,105,131,128,111,161,124,124,256,134,116,124,123,114,118,148,138,177,128,165,163,165,132,172,107,219,119,124,120,168,112,122,123,146,127,130,144,124,173,122,133,135,179,113,126,130,130,186,158,115,159,101,109,146,310,134,127,134,146,139,182,125,154,121,151,128,145,113,100,141,119,118,175,135,147,108,142,113,99,130,116,112,149,135,115,175,166,99,115,126,120,134,109,205],"xaxis":"x","y":[24.0,103.0,60.0,83.0,75.0,69.0,37.0,20.0,43.0,53.0,19.0,89.0,20.0,16.0,null,51.0,31.0,51.0,25.0,43.0,21.0,46.0,45.0,68.0,104.0,137.0,71.0,91.0,61.0,97.0,28.0,175.0,39.0,28.0,30.0,113.0,69.0,24.0,53.0,38.0,32.0,15.0,31.0,26.0,null,60.0,56.0,20.0,98.0,71.0,null,41.0,66.0,102.0,62.0,38.0,76.0,14.0,65.0,67.0,null,29.0,27.0,111.0,53.0,47.0,117.0,67.0,85.0,117.0,50.0,58.0,26.0,25.0,40.0,63.0,57.0,23.0,95.0,36.0,56.0,61.0,79.0,34.0,42.0,68.0,34.0,39.0,109.0,166.0,60.0,72.0,74.0,15.0,50.0,30.0,39.0,50.0,22.0,104.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f ...

# %%
fig2 = px.scatter(df_all , x = 'adist', y = 'dist', color='tag')

fig2.update_xaxes(title='Actual distance')
fig2.update_yaxes(title='Predicted - Actual')
fig2.update_layout(xaxis_range=[90,230])

fig2['layout']['legend']['title']['font_size'] = 20
fig2['layout']['legend']['font_size']=20
fig2['layout']['xaxis']['title']['font_size'] = 20
fig2['layout']['yaxis']['title']['font_size'] = 20

# %%
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1420360f-4c72-4f94-b838-c1d643467029" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1420360f-4c72-4f94-b838-c1d643467029")) {                    Plotly.newPlot(                        "1420360f-4c72-4f94-b838-c1d643467029",                        [{"hovertemplate":"tag=finetuned<br>adist=%{x}<br>dist=%{y}<extra></extra>","legendgroup":"finetuned","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"finetuned","orientation":"v","showlegend":true,"x":[126,183,127,169,162,160,128,105,131,128,111,161,124,124,256,134,116,124,123,114,118,148,138,177,128,165,163,165,132,172,107,219,119,124,120,168,112,122,123,146,127,130,144,124,173,122,133,135,179,113,126,130,130,186,158,115,159,101,109,146,310,134,127,134,146,139,182,125,154,121,151,128,145,113,100,141,119,118,175,135,147,108,142,113,99,130,116,112,149,135,115,175,166,99,115,126,120,134,109,205],"xaxis":"x","y":[-5.0,-15.0,-23.0,-2.0,11.0,-5.0,1.0,-11.0,-21.0,-8.0,-3.0,12.0,-24.0,-14.0,null,-14.0,-14.0,-10.0,-10.0,-4.0,-9.0,0.0,-24.0,-35.0,-26.0,14.0,2.0,-27.0,2.0,-2.0,-5.0,-6.0,-18.0,-16.0,1.0,-13.0,20.0,-3.0,9.0,-23.0,-7.0,-31.0,-33.0,-7.0,-6.0,2.0,-21.0,-24.0,-13.0,-4.0,null,-15.0,-9.0,-2.0,-18.0,-9.0,-30.0,7.0,12.0,-10.0,null,-24.0,-13.0,-5.0,-20.0,-10.0,12.0,4.0,13.0,-5.0,-19.0,-7.0,-15.0,7.0,12.0,-16.0,-1.0,-22.0,-11.0,-11.0,-26.0,-3.0,-8.0,-7.0,2.0,-1.0,2.0,1.0,-21.0,8.0,7.0,-34.0,-17.0,-4.0,9.0,-15.0,0.0,-13.0,-9.0,-15.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"tag=base<br>adist=%{x}<br>dist=%{y}<extra></extra>","legendgroup":"base","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"base","orientation":"v","showlegend":true,"x":[126,183,127,169,162,160,128,105,131,128,111,161,124,124,256,134,116,124,123,114,118,148,138,177,128,165,163,165,132,172,107,219,119,124,120,168,112,122,123,146,127,130,144,124,173,122,133,135,179,113,126,130,130,186,158,115,159,101,109,146,310,134,127,134,146,139,182,125,154,121,151,128,145,113,100,141,119,118,175,135,147,108,142,113,99,130,116,112,149,135,115,175,166,99,115,126,120,134,109,205],"xaxis":"x","y":[-102.0,-80.0,-67.0,-86.0,-87.0,-91.0,-91.0,-85.0,-88.0,-75.0,-92.0,-72.0,-104.0,-108.0,null,-83.0,-85.0,-73.0,-98.0,-71.0,-97.0,-102.0,-93.0,-109.0,-24.0,-28.0,-92.0,-74.0,-71.0,-75.0,-79.0,-44.0,-80.0,-96.0,-90.0,-55.0,-43.0,-98.0,-70.0,-108.0,-95.0,-115.0,-113.0,-98.0,null,-62.0,-77.0,-115.0,-81.0,-42.0,null,-89.0,-64.0,-84.0,-96.0,-77.0,-83.0,-87.0,-44.0,-79.0,null,-105.0,-100.0,-23.0,-93.0,-92.0,-65.0,-58.0,-69.0,-4.0,-101.0,-70.0,-119.0,-88.0,-60.0,-78.0,-62.0,-95.0,-80.0,-99.0,-91.0,-47.0,-63.0,-79.0,-57.0,-62.0,-82.0,-73.0,-40.0,31.0,-55.0,-103.0,-92.0,-84.0,-65.0,-96.0,-81.0,-84.0,-87.0,-101.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"] ...
